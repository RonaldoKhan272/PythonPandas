# %% [markdown]
# # Tips and Trick Python Pandas 32

# %% [markdown]
# # Plotting pada Pandas Data Frame

# %% [markdown]
# # Import Module

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.2.4
# 1.20.1

# %% [markdown]
# # Persiapan Data Frame

# %%
n_rows = 40
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)),
                 columns=cols)
df.head()
# Out:
#     A   B   C   D   E
# 0   2   6  12   7  11
# 1   3  11   6   7  16
# 2   1   6  12   4  13
# 3  13  13  10  17  15
# 4   3  19  13   3  18

# %% [markdown]
# # Line Plot

# %% [markdown]
# review data kolom

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   2   6  12   7  11
# 1   3  11   6   7  16
# 2   1   6  12   4  13
# 3  13  13  10  17  15
# 4   3  19  13   3  18

# %% [markdown]
# Visualisasi menjadi `line plot`

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df[['A', 'B']].plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bar Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   2   6  12   7  11
# 1   3  11   6   7  16
# 2   1   6  12   4  13
# 3  13  13  10  17  15
# 4   3  19  13   3  18

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A', 'B']].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A', 'B']].head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A', 'B']].head().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Area Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   2   6  12   7  11
# 1   3  11   6   7  16
# 2   1   6  12   4  13
# 3  13  13  10  17  15
# 4   3  19  13   3  18

# %%
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df[['A', 'B']].head().plot(kind='area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Box Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   2   6  12   7  11
# 1   3  11   6   7  16
# 2   1   6  12   4  13
# 3  13  13  10  17  15
# 4   3  19  13   3  18

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Histogram

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   2   6  12   7  11
# 1   3  11   6   7  16
# 2   1   6  12   4  13
# 3  13  13  10  17  15
# 4   3  19  13   3  18

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['A', 'B']].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Kernel Density Estimation (KDE)

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   2   6  12   7  11
# 1   3  11   6   7  16
# 2   1   6  12   4  13
# 3  13  13  10  17  15
# 4   3  19  13   3  18

# %%
df.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Scatter Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   2   6  12   7  11
# 1   3  11   6   7  16
# 2   1   6  12   4  13
# 3  13  13  10  17  15
# 4   3  19  13   3  18

# %%
df.plot(x='A', y='B', kind='scatter')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>
